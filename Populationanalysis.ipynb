# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("A:\data analytics projexxts\Population\population.csv")

# %%
data.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
yearly_change=data['Yearly Change']

# %%
yearly_chang=[ i.replace("%","").replace(" ","") for i in yearly_change ]

# %%
yearly_chang=[float(i) for i in yearly_chang]

# %%
data['yearlyChange']=yearly_chang

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share', 'yearlyChange'],
#       dtype='object')

# %% [markdown]
# # Top 5 countires with highest %age change in population in 2020

# %%
yearly_highest_change=data.nlargest(5,'yearlyChange').iloc[:,[0,11]]

# %%
plt.figure(figsize=(8,4))
plt.bar(yearly_highest_change["Country (or dependency)"],yearly_highest_change['yearlyChange'])
plt.title("5 countires with highest yearly percentage change in population")
# Out:
# Text(0.5, 1.0, '5 countires with highest yearly percentage change in population')

# %% [markdown]
# # Countries with highest land area

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share', 'yearlyChange'],
#       dtype='object')

# %%
highest_area=data.nlargest(5,'Land Area (Km²)').iloc[:,[0,5]]

# %%
plt.figure(figsize=(7,4))
plt.bar(highest_area["Country (or dependency)"],highest_area['Land Area (Km²)'])
plt.title("Top 5 countires with highest area")
# Out:
# Text(0.5, 1.0, 'Top 5 countires with highest area')

# %% [markdown]
# # Countries with largest net migration

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share', 'yearlyChange'],
#       dtype='object')

# %%
highest_migration=data.nlargest(5,'Migrants (net)').iloc[:,[0,6]]

# %%
plt.figure(figsize=(7,4))
plt.bar(highest_migration["Country (or dependency)"],highest_migration['Migrants (net)'])
plt.title("Top 5 countires with highest migration")
# Out:
# Text(0.5, 1.0, 'Top 5 countires with highest migration')

# %% [markdown]
# # countries with highest urban population

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share', 'yearlyChange'],
#       dtype='object')

# %%
urban_population=data['Urban Pop %']
urban_pupulation=[i.replace("%","").replace(" ","").replace("N.A.","0") for i in urban_population]

# %%
urban_pupulation=[int(i) for i in urban_pupulation]

# %%
data["Urban pop"]=urban_pupulation

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share', 'yearlyChange',
#        'Urban pop'],
#       dtype='object')

# %%
highest_urban_pop=data.nlargest(5,'Urban pop').iloc[:,[0,12]]

# %%
plt.figure(figsize=(9,4))
plt.bar(highest_urban_pop["Country (or dependency)"],highest_urban_pop['Urban pop'])
plt.title("Top 5 countries with highest %age Urban population")
plt.ylabel("%age pop")
plt.xlabel("countries",fontsize=15)
# Out:
# Text(0.5, 0, 'countries')
